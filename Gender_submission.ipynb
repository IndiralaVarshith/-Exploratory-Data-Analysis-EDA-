# %%
import pandas as pd


df = pd.read_csv('gender_submission.csv')

# Check
print(df.head())
# Out:
#    PassengerId  Survived
# 0          892         0
# 1          893         1
# 2          894         0
# 3          895         0
# 4          896         1

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
file_path = 'gender_submission.csv'

if os.path.exists(file_path):
    df = pd.read_csv(file_path)
    print("Dataset Loaded Successfully!")
else:
    print(f"File {file_path} not found. Please upload it to the working directory.")
# Out:
# Dataset Loaded Successfully!

# %%
print("\nFirst 5 Rows:")
print(df.head())
# Out:
# First 5 Rows:
#    PassengerId  Survived
# 0          892         0
# 1          893         1
# 2          894         0
# 3          895         0
# 4          896         1

# %%
print("\nShape of the dataset:")
print(df.shape)
# Out:
# Shape of the dataset:
# (418, 2)

# %%
print("\nInfo about dataset:")
print(df.info())
# Out:
# Info about dataset:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Survived     418 non-null    int64
# dtypes: int64(2)
# memory usage: 6.7 KB
# None

# %%
print("\nStatistical Summary:")
print(df.describe())
# Out:
# Statistical Summary:
#        PassengerId    Survived
# count   418.000000  418.000000
# mean   1100.500000    0.363636
# std     120.810458    0.481622
# min     892.000000    0.000000
# 25%     996.250000    0.000000
# 50%    1100.500000    0.000000
# 75%    1204.750000    1.000000
# max    1309.000000    1.000000

# %%
print("\nMissing Values per Column:")
print(df.isnull().sum())
# Out:
# Missing Values per Column:
# PassengerId    0
# Survived       0
# dtype: int64

# %%
for column in df.columns:
    print(f"\nValue Counts for {column}:")
    print(df[column].value_counts())
# Out:
# Value Counts for PassengerId:
# PassengerId
# 1309    1
# 892     1
# 1293    1
# 1292    1
# 1291    1
#        ..
# 898     1
# 897     1
# 896     1
# 895     1
# 894     1
# Name: count, Length: 418, dtype: int64
#
# Value Counts for Survived:
# Survived
# 0    266
# 1    152
# Name: count, dtype: int64

# %%
df.hist(figsize=(10, 6), edgecolor='black')
plt.suptitle('Histograms of Features', fontsize=16)
plt.show()

# %%
for column in df.select_dtypes(include=['int64', 'float64']).columns:
    plt.figure(figsize=(6, 4))
    sns.boxplot(y=df[column])
    plt.title(f'Boxplot of {column}', fontsize=14)
    plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.heatmap(df.corr(), annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap', fontsize=16)
plt.show()

# %%
sns.pairplot(df, hue='Survived')
plt.suptitle('Pairplot', y=1.02, fontsize=16)
plt.show()

# %%
print("\n--- Summary of Findings ---")
print("- No missing values in the dataset.")
print("- 'PassengerId' is just an identifier, no meaningful relationship with 'Survived'.")
print("- 'Survived' distribution needs to be checked — usually, slightly fewer survived than perished.")
print("- No strong correlations since there are only two columns of meaning.")
print("- More features like Age, Fare, Sex would help deeper analysis.")
# Out:
# --- Summary of Findings ---
# - No missing values in the dataset.
# - 'PassengerId' is just an identifier, no meaningful relationship with 'Survived'.
# - 'Survived' distribution needs to be checked — usually, slightly fewer survived than perished.
# - No strong correlations since there are only two columns of meaning.
# - More features like Age, Fare, Sex would help deeper analysis.
